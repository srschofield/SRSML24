# %% [markdown]
# # Process MTRX data to JPG
# Use this notebook to load Scienta Omicron Matrix format SPM data and save as image JPG.
#
# **Author**: Steven R. Schofield
# **Created**: November, 2024

# %%
# For file path operations
import os

# %%
# Path to data processing module
module_path_list = [
    '/Users/steven/academic-iCloud/Python/modules',
    '/hpc/srs/Python/modules'
] 

module_path = next((p for p in module_path_list if os.path.exists(p)), None)
if not module_path:
    exit("No valid module paths.")
else:
    print('module_path = {}'.format(module_path))
# Out:
# module_path = /Users/steven/academic-iCloud/Python/modules

# %%
# # Ensure modules are reloaded 
# %load_ext autoreload
# %autoreload 2

# Import standard modules
import os, sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps  # Import the new colormap module

# Add custom module path to list
sys.path.append(module_path)

# Import custom module
import SRSML24.data_prep as dp
import SRSML24.model as m
import SRSML24.utils as ut

m.print_system_info()

start_time = dp.current_datetime()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Python version: 3.8.20 (default, Oct  3 2024, 10:22:23)
# [Clang 14.0.6 ]
# TensorFlow version: 2.13.0
# TensorFlow is built with CUDA: False
# TensorFlow is built with ROCm: False
#
# System: Darwin 24.6.0 (arm64)
# Platform: macOS-15.7.4-arm64-arm-64bit
# Processor: arm
#
# Number of GPUs available to TensorFlow: 1
# GPU Device: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
# >>> Running with GPU available <<<  (macOS-15.7.4-arm64-arm-64bit)
#
# Current time 2026-03-05 19:39:00

# %%
# The working direcroryt should contain a subfolder 'mtrx' that contains the matrix image data. They can be in subfolders
working_directory = '/Users/steven/Python-data-SiC-Mischa'
output_directory = 'jpg'

# %%
job_data_path = dp.create_new_data_path(working_directory, output_directory, include_date=False)
mtrx_path = dp.create_new_data_path(working_directory, 'mtrx', include_date=False)

if not working_directory:
    exit("No valid data paths.")
else:
    print('Top   : {}'.format(working_directory))
    print('Read  : {}'.format(mtrx_path))
    print('Write : {}'.format(job_data_path))
# Out:
# Top   : /Users/steven/Python-data-SiC-Mischa
# Read  : /Users/steven/Python-data-SiC-Mischa/mtrx
# Write : /Users/steven/Python-data-SiC-Mischa/jpg

# %%
# Training data
mtrx_file_list, _ = dp.list_files_by_extension(mtrx_path,'Z_mtrx',verbose=False)
# Out:
# Found 124 files with extension 'Z_mtrx' in directory:
# /Users/steven/Python-data-SiC-Mischa/mtrx

# %%
colormapname = 'viridis'
colormapname = 'gist_heat'

dp.process_mtrx_files(
    mtrx_file_list,
    job_data_path, # save data path
    flatten_method = 'poly_xy',
    save_windows = False,
    save_jpg = True,
    save_meta = True,
    save_meta_data_on_jpg = True,
    save_window_jpgs = False,
    collate = True,
    data_scaling=1e9,
    pixel_ratio = 0.1,
    resample = False,
    pixel_density = 15,
    pixel_limit = 100000,
    cmap = colormapname,
    verbose = False
    )
# Out:
# There are 124 files to process
# ..jFriday, 12 February 2016 09:48:48
# jFriday, 12 February 2016 09:48:48
# jFriday, 12 February 2016 10:16:57
# jFriday, 12 February 2016 10:16:57
# jFriday, 12 February 2016 10:16:57
# jFriday, 12 February 2016 10:16:57
# jFriday, 12 February 2016 10:40:18
# jFriday, 12 February 2016 10:40:18
# jFriday, 12 February 2016 10:40:18
# jFriday, 12 February 2016 10:40:18
# jFriday, 12 February 2016 10:48:11
# jFriday, 12 February 2016 10:48:11
# jFriday, 12 February 2016 10:48:11
# jFriday, 12 February 2016 10:48:11
# jFriday, 12 February 2016 10:55:36
# jFriday, 12 February 2016 10:55:36
# jFriday, 12 February 2016 10:55:36
# jFriday, 12 February 2016 10:55:36
# jFriday, 12 February 2016 11:03:01
# jFriday, 12 February 2016 11:03:01
# jFriday, 12 February 2016 11:03:01
# jFriday, 12 February 2016 11:03:01
# jFriday, 12 February 2016 11:10:35
# jFriday, 12 February 2016 11:10:35
# jFriday, 12 February 2016 11:10:35
# jFriday, 12 February 2016 11:10:35
# .jFriday, 12 February 2016 11:11:50
# jFriday, 12 February 2016 11:11:50
# .jFriday, 12 February 2016 11:13:16
# jFriday, 12 February 2016 11:13:16
# jFriday, 12 February 2016 11:27:50
# jFriday, 12 February 2016 11:27:50
# jFriday, 12 February 2016 11:27:50
# jFriday, 12 February 2016 11:27:50
# jFriday, 12 February 2016 11:32:00
# jFriday, 12 February 2016 11:32:00
# jFriday, 12 February 2016 11:39:51
# jFriday, 12 February 2016 11:39:51
# jFriday, 12 February 2016 11:39:51
# jFriday, 12 February 2016 11:39:51
# jFriday, 12 February 2016 11:41:42
# jFriday, 12 February 2016 11:41:42
# jFriday, 12 February 2016 11:54:11
# jFriday, 12 February 2016 11:54:11
# jFriday, 12 February 2016 11:54:11
# jFriday, 12 February 2016 11:54:11
# jFriday, 12 February 2016 11:55:48
# jFriday, 12 February 2016 11:55:48
# jThursday, 11 February 2016 14:10:16
# jThursday, 11 February 2016 14:10:16
# jThursday, 11 February 2016 14:11:34
# jThursday, 11 February 2016 14:11:34
# jFriday, 12 February 2016 11:58:39
# jFriday, 12 February 2016 11:58:39
# jFriday, 12 February 2016 12:00:22
# jFriday, 12 February 2016 12:00:22
# jFriday, 12 February 2016 12:03:08
# jFriday, 12 February 2016 12:03:08
# .jFriday, 12 February 2016 12:05:08
# jFriday, 12 February 2016 12:05:08
# .jFriday, 12 February 2016 12:08:39
# jFriday, 12 February 2016 12:08:39
# jFriday, 12 February 2016 12:09:33
# jFriday, 12 February 2016 12:09:33
# jFriday, 12 February 2016 12:11:33
# jFriday, 12 February 2016 12:11:33
# jFriday, 12 February 2016 12:13:01
# jFriday, 12 February 2016 12:13:01
# .jFriday, 12 February 2016 12:21:26
# jFriday, 12 February 2016 12:21:26
# jFriday, 12 February 2016 12:21:26
# jFriday, 12 February 2016 12:21:26
# .jFriday, 12 February 2016 12:30:09
# jFriday, 12 February 2016 12:30:09
# jFriday, 12 February 2016 12:30:09
# jFriday, 12 February 2016 12:30:09
# jFriday, 12 February 2016 12:38:38
# jFriday, 12 February 2016 12:38:38
# jFriday, 12 February 2016 12:38:38
# jFriday, 12 February 2016 12:38:38
# jFriday, 12 February 2016 12:44:48
# jFriday, 12 February 2016 12:44:48
# jFriday, 12 February 2016 12:44:48
# jFriday, 12 February 2016 12:44:48
# .jFriday, 12 February 2016 14:41:18
# jFriday, 12 February 2016 14:41:18
# jFriday, 12 February 2016 15:06:48
# jFriday, 12 February 2016 15:06:48
# jFriday, 12 February 2016 15:06:48
# jFriday, 12 February 2016 15:06:48
# jFriday, 12 February 2016 15:32:07
# jFriday, 12 February 2016 15:32:07
# jFriday, 12 February 2016 15:32:07
# jFriday, 12 February 2016 15:32:07
# jFriday, 12 February 2016 15:36:48
# jFriday, 12 February 2016 15:36:48
# jFriday, 12 February 2016 15:41:48
# jFriday, 12 February 2016 15:41:48
# jFriday, 12 February 2016 15:41:48
# jFriday, 12 February 2016 15:41:48
# jFriday, 12 February 2016 16:08:17
# jFriday, 12 February 2016 16:08:17
# jFriday, 12 February 2016 16:08:17
# jFriday, 12 February 2016 16:08:17
# jFriday, 12 February 2016 16:11:52
# jFriday, 12 February 2016 16:11:52
# jFriday, 12 February 2016 16:19:40
# jFriday, 12 February 2016 16:19:40
# jFriday, 12 February 2016 16:19:40
# jFriday, 12 February 2016 16:19:40
# ...jFriday, 12 February 2016 16:27:49
# jFriday, 12 February 2016 16:27:49
# jFriday, 12 February 2016 16:27:49
# jFriday, 12 February 2016 16:27:49
# .jFriday, 12 February 2016 16:38:58
# jFriday, 12 February 2016 16:38:58
# jFriday, 12 February 2016 16:45:12
# jFriday, 12 February 2016 16:45:12
# jFriday, 12 February 2016 16:50:37
# jFriday, 12 February 2016 16:50:37
# jFriday, 12 February 2016 16:56:11
# jFriday, 12 February 2016 16:56:11
# .jFriday, 12 February 2016 17:03:47
# jFriday, 12 February 2016 17:03:47
# jFriday, 12 February 2016 17:03:47
# jFriday, 12 February 2016 17:03:47
# jFriday, 12 February 2016 17:11:12
# jFriday, 12 February 2016 17:11:12
# jFriday, 12 February 2016 17:11:12
# jFriday, 12 February 2016 17:11:12
# jFriday, 12 February 2016 17:13:42
# jFriday, 12 February 2016 17:13:42
# .jFriday, 12 February 2016 17:21:30
# jFriday, 12 February 2016 17:21:30
# jFriday, 12 February 2016 17:21:30
# jFriday, 12 February 2016 17:21:30
# ..jFriday, 12 February 2016 17:46:42
# jFriday, 12 February 2016 17:46:42
# jFriday, 12 February 2016 17:55:56
# jFriday, 12 February 2016 17:55:56
# jFriday, 12 February 2016 17:55:56
# jFriday, 12 February 2016 17:55:56
# jFriday, 12 February 2016 18:00:38
# jFriday, 12 February 2016 18:00:38
# jFriday, 12 February 2016 18:08:27
# jFriday, 12 February 2016 18:08:27
# jFriday, 12 February 2016 18:08:27
# jFriday, 12 February 2016 18:08:27
# jFriday, 12 February 2016 18:15:52
# jFriday, 12 February 2016 18:15:52
# jFriday, 12 February 2016 18:15:52
# jFriday, 12 February 2016 18:15:52
# jFriday, 12 February 2016 18:23:17
# jFriday, 12 February 2016 18:23:17
# jFriday, 12 February 2016 18:23:17
# jFriday, 12 February 2016 18:23:17
# .jFriday, 12 February 2016 18:30:56
# jFriday, 12 February 2016 18:30:56
# jFriday, 12 February 2016 18:30:56
# jFriday, 12 February 2016 18:30:56
# jFriday, 12 February 2016 18:38:21
# jFriday, 12 February 2016 18:38:21
# jFriday, 12 February 2016 18:38:21
# jFriday, 12 February 2016 18:38:21
# jFriday, 12 February 2016 18:45:46
# jFriday, 12 February 2016 18:45:46
# jFriday, 12 February 2016 18:45:46
# jFriday, 12 February 2016 18:45:46
# jFriday, 12 February 2016 18:53:11
# jFriday, 12 February 2016 18:53:11
# jFriday, 12 February 2016 18:53:11
# jFriday, 12 February 2016 18:53:11
# jFriday, 12 February 2016 19:00:36
# jFriday, 12 February 2016 19:00:36
# jFriday, 12 February 2016 19:00:36
# jFriday, 12 February 2016 19:00:36
# jFriday, 12 February 2016 19:02:43
# jFriday, 12 February 2016 19:02:43
# jFriday, 12 February 2016 19:07:35
# jFriday, 12 February 2016 19:07:35
# jFriday, 12 February 2016 19:19:05
# jFriday, 12 February 2016 19:19:05
# jFriday, 12 February 2016 19:19:05
# jFriday, 12 February 2016 19:19:05
# jFriday, 12 February 2016 19:35:08
# jFriday, 12 February 2016 19:35:08
# jFriday, 12 February 2016 19:42:20
# jFriday, 12 February 2016 19:42:20
# jFriday, 12 February 2016 19:52:38
# jFriday, 12 February 2016 19:52:38
# jFriday, 12 February 2016 19:58:24
# jFriday, 12 February 2016 19:58:24
# jFriday, 12 February 2016 20:08:33
# jFriday, 12 February 2016 20:08:33
# .jFriday, 12 February 2016 20:18:42
# jFriday, 12 February 2016 20:18:42
# .jFriday, 12 February 2016 20:20:29
# jFriday, 12 February 2016 20:20:29
# ..jFriday, 12 February 2016 20:22:57
# jFriday, 12 February 2016 20:22:57
# jFriday, 12 February 2016 20:34:50
# jFriday, 12 February 2016 20:34:50
# jFriday, 12 February 2016 20:34:50
# jFriday, 12 February 2016 20:34:50
# .jFriday, 12 February 2016 20:37:41
# jFriday, 12 February 2016 20:37:41
# jFriday, 12 February 2016 20:37:41
# jFriday, 12 February 2016 20:37:41
# .jSaturday, 13 February 2016 00:35:12
# jSaturday, 13 February 2016 00:35:12
# jSaturday, 13 February 2016 04:32:16
# jSaturday, 13 February 2016 04:32:16
# jSaturday, 13 February 2016 08:29:19
# .jSaturday, 13 February 2016 09:50:17
# jSaturday, 13 February 2016 09:50:17
#  100
# jSaturday, 13 February 2016 10:36:26
# jSaturday, 13 February 2016 10:36:26
# jSaturday, 13 February 2016 10:41:33
# jSaturday, 13 February 2016 10:41:33
# jSaturday, 13 February 2016 10:46:41
# jSaturday, 13 February 2016 10:46:41
# jSaturday, 13 February 2016 10:51:48
# jSaturday, 13 February 2016 10:51:48
# jSaturday, 13 February 2016 10:56:56
# jSaturday, 13 February 2016 10:56:56
# jSaturday, 13 February 2016 11:02:03
# jSaturday, 13 February 2016 11:02:03
# jSaturday, 13 February 2016 11:07:11
# jSaturday, 13 February 2016 11:07:11
# jSaturday, 13 February 2016 11:12:19
# jSaturday, 13 February 2016 11:12:19
# jSaturday, 13 February 2016 11:17:26
# jSaturday, 13 February 2016 11:17:26
# jSaturday, 13 February 2016 11:22:34
# jSaturday, 13 February 2016 11:22:34
# jSaturday, 13 February 2016 09:55:25
# jSaturday, 13 February 2016 09:55:25
# jSaturday, 13 February 2016 11:25:11
# jSaturday, 13 February 2016 11:25:11
# jSaturday, 13 February 2016 10:00:32
# jSaturday, 13 February 2016 10:00:32
# jSaturday, 13 February 2016 10:05:40
# jSaturday, 13 February 2016 10:05:40
# jSaturday, 13 February 2016 10:10:48
# jSaturday, 13 February 2016 10:10:48
# jSaturday, 13 February 2016 10:15:55
# jSaturday, 13 February 2016 10:15:55
# jSaturday, 13 February 2016 10:21:03
# jSaturday, 13 February 2016 10:21:03
# jSaturday, 13 February 2016 10:26:10
# jSaturday, 13 February 2016 10:26:10
# jSaturday, 13 February 2016 10:31:18
# jSaturday, 13 February 2016 10:31:18
# ......
# ********************
# Conversion complete.
# ********************
